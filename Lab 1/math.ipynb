# %%
import numpy as np

# %%
np.exp(2.72)
# Out:
# 15.1803222449539

# %%
np.exp(np.log(np.e))
# Out:
# 2.718281828459045

# %%
sigma = 1
mu = 0
1 / (np.sqrt(np.pi * 2) * sigma)  * np.exp( -0.5*( 1.2 - mu / sigma ) ** 2)
# Out:
# 0.19418605498321295

# %%
sigma = 0.5
mu = 0
1 / (np.sqrt(np.pi * 2) * sigma)  * np.exp( -0.5*( (1.2 - mu) / sigma ) ** 2)
# Out:
# 0.0447890605896858

# %%
sigma = 2.5
mu = 1
1 / (np.sqrt(np.pi * 2)* sigma)  * np.exp( -0.5*( (1.2 - mu)/ sigma ) ** 2)
# Out:
# 0.15906708220464358
